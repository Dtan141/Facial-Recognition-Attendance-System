# %%
from flask import render_template
import torch
from blazeface.blazeface import BlazeFace
# Load models
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
blazeface = BlazeFace().to(device)
blazeface.load_weights("blazeface.pth")
blazeface.load_anchors("anchors.npy")
blazeface.min_score_thresh = 0.7
blazeface.min_suppression_threshold = 0.3
blazeface.eval()

facenet = torch.jit.load("models/mobilefacenet_scripted.pt", map_location=device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# BlazeFace (PyTorch nn.Module bình thường)
print("BlazeFace trainable params:", count_parameters(blazeface))

# MobileFaceNet (đang ở dạng TorchScript)
# TorchScript không có .parameters() trực tiếp, cần chuyển về nn.Module nếu có thể
try:
    print("MobileFaceNet trainable params:", count_parameters(facenet))
except AttributeError:
    # Nếu không truy cập được parameters(), cần load model gốc nn.Module
    print("MobileFaceNet TorchScript không hỗ trợ .parameters(). Cần load nn.Module để đếm tham số.")
# Out:
# BlazeFace trainable params: 101390
# MobileFaceNet trainable params: 999936

# %%
# !pip uninstall torch torchvision -y
# !pip install torch==2.2.0+cpu torchvision==0.17.0+cpu --index-url https://download.pytorch.org/whl/cpu
# Out:
# Found existing installation: torch 2.2.2
# Uninstalling torch-2.2.2:
#   Successfully uninstalled torch-2.2.2
# Found existing installation: torchvision 0.17.2
# Uninstalling torchvision-0.17.2:
#   Successfully uninstalled torchvision-0.17.2
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.2.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.2.0%2Bcpu-cp310-cp310-win_amd64.whl (200.8 MB)
#      ---------------------------------------- 0.0/200.8 MB ? eta -:--:--
#       -------------------------------------- 3.4/200.8 MB 18.3 MB/s eta 0:00:11
#      - ------------------------------------- 9.2/200.8 MB 22.9 MB/s eta 0:00:09
#      -- ----------------------------------- 15.7/200.8 MB 26.1 MB/s eta 0:00:08
#      ---- --------------------------------- 24.1/200.8 MB 29.4 MB/s eta 0:00:07
#      ------ ------------------------------- 32.2/200.8 MB 31.5 MB/s eta 0:00:06
#      ------- ------------------------------ 39.6/200.8 MB 32.3 MB/s eta 0:00:05
#      -------- ----------------------------- 46.1/200.8 MB 31.9 MB/s eta 0:00:05
#      ---------- --------------------------- 53.2/200.8 MB 32.0 MB/s eta 0:00:05
#      ----------- -------------------------- 60.3/200.8 MB 32.3 MB/s eta 0:00:05
#      ------------- ------------------------ 69.5/200.8 MB 33.3 MB/s eta 0:00:04
#      -------------- ----------------------- 76.8/200.8 MB 33.6 MB/s eta 0:00:04
#      ---------------- --------------------- 85.5/200.8 MB 34.1 MB/s eta 0:00:04
#      ----------------- -------------------- 93.6/200.8 MB 34.7 MB/s eta 0:00:04
#      ------------------ ------------------ 101.2/200.8 MB 35.1 MB/s eta 0:00:03
#      -------------------- ---------------- 109.8/200.8 MB 35.2 MB/s eta 0:00:03
#      --------------------- --------------- 118.2/200.8 MB 35.6 MB/s eta 0:00:03
#      ----------------------- ------------- 126.9/200.8 MB 35.9 MB/s eta 0:00:03
#      ------------------------- ----------- 135.8/200.8 MB 36.1 MB/s eta 0:00:02
#      -------------------------- ---------- 145.0/200.8 MB 36.6 MB/s eta 0:00:02
#      ---------------------------- -------- 152.6/200.8 MB 36.6 MB/s eta 0:00:02
#      ----------------------------- ------- 161.5/200.8 MB 36.7 MB/s eta 0:00:02
#      ------------------------------- ----- 170.4/200.8 MB 37.2 MB/s eta 0:00:01
#      -------------------------------- ---- 178.5/200.8 MB 37.2 MB/s eta 0:00:01
#      ---------------------------------- -- 188.2/200.8 MB 37.5 MB/s eta 0:00:01
#      ------------------------------------  195.8/200.8 MB 37.4 MB/s eta 0:00:01
#      ------------------------------------  200.5/200.8 MB 37.5 MB/s eta 0:00:01
#      ------------------------------------  200.5/200.8 MB 37.5 MB/s eta 0:00:01
#      ------------------------------------  200.5/200.8 MB 37.5 MB/s eta 0:00:01
#      ------------------------------------  200.5/200.8 MB 37.5 MB/s eta 0:00:01
#      ------------------------------------- 200.8/200.8 MB 32.9 MB/s eta 0:00:00
# Collecting torchvision==0.17.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.17.0%2Bcpu-cp310-cp310-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      ---------------------------------------- 1.2/1.2 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (4.12.2)
# Requirement already satisfied: sympy in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (1.13.3)
# Requirement already satisfied: networkx in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torch==2.2.0+cpu) (2024.6.1)
# Requirement already satisfied: numpy in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torchvision==0.17.0+cpu) (1.26.4)
# Requirement already satisfied: requests in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torchvision==0.17.0+cpu) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from torchvision==0.17.0+cpu) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from jinja2->torch==2.2.0+cpu) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from requests->torchvision==0.17.0+cpu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from requests->torchvision==0.17.0+cpu) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from requests->torchvision==0.17.0+cpu) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from requests->torchvision==0.17.0+cpu) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\miniconda3\envs\face_reg\lib\site-packages (from sympy->torch==2.2.0+cpu) (1.3.0)
# Installing collected packages: torch, torchvision
#
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    ---------------------------------------- 0/2 [torch]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchvision]
#    ---------------------------------------- 2/2 [torchvision]
#
# Successfully installed torch-2.2.0+cpu torchvision-0.17.0+cpu
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0+cpu requires torch==2.8.0, but you have torch 2.2.0+cpu which is incompatible.

# %%
# !pip install facenet-pytorch

# %%
# !pip install faiss-cpu==1.7.4

# %%
import torch
import cv2
import os
import numpy as np
import torch.nn.functional as F
from torchvision import transforms
import matplotlib.pyplot as plt
from facenet_pytorch import InceptionResnetV1
from blazeface import BlazeFace
import faiss
import pickle
import shutil

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 6
#       4 import numpy as np
#       5 import torch.nn.functional as F
# ----> 6 from torchvision import transforms
#       7 import matplotlib.pyplot as plt
#       8 from facenet_pytorch import InceptionResnetV1
#
# File c:\Users\HP\miniconda3\envs\face_reg\lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File c:\Users\HP\miniconda3\envs\face_reg\lib\site-packages\torchvision\_meta_registrations.py:26
#      20         return fn
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#      28     torch._check(
#      29         input.dtype == rois.dtype,
#      30         lambda: (
#    (...)
#      33         ),
#      34     )
#
# File c:\Users\HP\miniconda3\envs\face_reg\lib\site-packages\torchvision\_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#      20     return fn
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)

# %%
import pickle
index_path = r'D:\PROJECT\ATTENDANCE SYSTEM\face_index.faiss'
id_mapping_path = r'D:\PROJECT\ATTENDANCE SYSTEM\face_ids.pkl'

with open(id_mapping_path, 'rb') as f:
    face_ids = pickle.load(f)
print(type(face_ids))
print(face_ids)
# Out:
# <class 'list'>
# ['Leonardo DiCaprio', 'Will Smith', 'Angelina Jolie', 'Brad Pitt', 'Denzel Washington', 'Hugh Jackman', 'Jennifer Lawrence', 'Johnny Depp', 'Kate Winslet', 'Megan Fox', 'Natalie Portman', 'Nicole Kidman', 'Robert Downey Jr', 'Sandra Bullock', 'Scarlett Johansson', 'Tom Cruise', 'Tom Hanks', 'Vy Trinh', 'Trang Vu', 'Tan Nguyen', 'Lay Duong', 'Ky Lao', 'Ha Chu', 'Bich Phuong', 'Chi Pu', 'Doan Quoc Dam', 'Dung Hoang', 'Ha Ho', 'Kha Ngan', 'Minzy Hoa', 'Nhi', 'Phuc Duc', 'Taylor Swift', 'Thinh Noo', 'Thuy Chi', 'Tuan Ha', 'Tung Son', 'Van Mai', 'Dao Duong', 'Bao Ngoc', 'Chau Bui', 'Hong Nhung', 'Manh Truong', 'My Linh', 'Phuong Hang', 'Trang Phap', 'Truong My Lan', 'Uyen Linh', 'Cat Tuong', 'Tung']

# %%
import torch
print("Torch:", torch.__version__)
# Out:
# Torch: 2.8.0+cpu

# %% [markdown]
# ### CREATE FAISS

# %%
def create_faiss_from_images(input_folder_path, index_path, id_mapping_path, blazeface_path, anchors_path):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Load BlazeFace
    front_net = BlazeFace().to(device)
    front_net.load_weights(blazeface_path)
    front_net.load_anchors(anchors_path)
    front_net.min_score_thresh = 0.7
    front_net.min_suppression_threshold = 0.3
    front_net.eval()

    # Load FaceNet
    facenet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

    face_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])

    face_vectors = []
    face_ids = []

    for filename in os.listdir(input_folder_path):
        if not filename.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        img_path = os.path.join(input_folder_path, filename)
        img = cv2.imread(img_path)
        if img is None:
            print(f"Lỗi đọc ảnh: {filename}")
            continue

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (128, 128))
        h, w, _ = img.shape

        detections = front_net.predict_on_image(img)
        if len(detections) == 0:
            print(f"Không phát hiện khuôn mặt: {filename}")
            continue

        for det in detections:
            ymin, xmin, ymax, xmax = det[:4]
            x1 = int(xmin * w)
            y1 = int(ymin * h)
            x2 = int(xmax * w)
            y2 = int(ymax * h)

            face_crop = img[y1:y2, x1:x2]
            if face_crop.size == 0:
                continue

            face_tensor = face_transform(face_crop).unsqueeze(0).to(device)
            with torch.no_grad():
                embedding = facenet(face_tensor)
                embedding = F.normalize(embedding)

            vector = embedding.squeeze(0).cpu().numpy().astype('float32')
            face_vectors.append(vector)

            student_id = os.path.splitext(filename)[0]
            face_ids.append(student_id)

            print(f"Đã thêm vector cho: {student_id}")

    # Convert sang numpy
    if len(face_vectors) == 0:
        print("❌ Không có vector nào để build index.")
        return

    face_vectors_np = np.array(face_vectors, dtype='float32')
    d = face_vectors_np.shape[1]
    n_data = face_vectors_np.shape[0]

    print(f"\n📦 Tổng số vector: {n_data}")

    # Tùy vào số lượng vector mà chọn index phù hợp
    if n_data < 10:
        print("⚠️ Dữ liệu ít, dùng IndexFlatL2 (RAM cao).")
        index = faiss.IndexFlatL2(d)
        index.add(face_vectors_np)
    else:
        quantizer = faiss.IndexFlatL2(d)
        nlist = min(100, n_data // 2)
        if nlist < 1:
            nlist = 1
        print(f"⚙️ Dùng IndexIVFFlat với {nlist} cụm...")
        index = faiss.IndexIVFFlat(quantizer, d, nlist)
        print("⏳ Train index...")
        index.train(face_vectors_np)
        index.add(face_vectors_np)

    # Lưu index và ID mapping
    faiss.write_index(index, index_path)
    with open(id_mapping_path, 'wb') as f:
        pickle.dump(face_ids, f)

    print(f"\n✅ Đã tạo FAISS index với {n_data} vector.")

# %% [markdown]
# ### RECOGNIZE IMAGE AND EVALUATE

# %%
class FaceRecognizer:
    def __init__(self, blazeface_path, anchors_path, index_path, id_mapping_path, threshold=0.95, device='cuda'):
        self.device = torch.device(device if torch.cuda.is_available() else 'cpu')
        self.threshold = threshold

        # Load BlazeFace
        self.detector = BlazeFace().to(self.device)
        self.detector.load_weights(blazeface_path)
        self.detector.load_anchors(anchors_path)
        self.detector.min_score_thresh = 0.7
        self.detector.min_suppression_threshold = 0.3
        self.detector.eval()

        # Load FaceNet
        self.facenet = InceptionResnetV1(pretrained='vggface2').eval().to(self.device)

        # Load FAISS index & ID mapping
        self.index = faiss.read_index(index_path)
        with open(id_mapping_path, 'rb') as f:
            self.face_ids = pickle.load(f)

        # Preprocess
        self.face_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((160, 160)),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])
        ])

        print("📂 FAISS index loaded:")
        print(" - Số vector:", self.index.ntotal)
        print(" - Loại index:", type(self.index))
        print(" - Chiều vector:", self.index.d)


    def recognize(self, img_path, show=False):
        img_orig = cv2.imread(img_path)
        if img_orig is None:
            print("❌ Không đọc được ảnh:", img_path)
            return "Invalid", None

        img_rgb = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
        img_small = cv2.resize(img_rgb, (128, 128))
        h, w = img_orig.shape[:2]

        # Detect face
        detections = self.detector.predict_on_image(img_small)
        if len(detections) == 0:
            print("❌ Không phát hiện khuôn mặt.")
            return "NoFace", None

        for det in detections:
            ymin, xmin, ymax, xmax = det[:4]
            x1, y1, x2, y2 = int(xmin * w), int(ymin * h), int(xmax * w), int(ymax * h)
            face_crop = img_rgb[y1:y2, x1:x2]
            if face_crop.size == 0:
                continue

            # Embedding
            face_tensor = self.face_transform(face_crop).unsqueeze(0).to(self.device)
            with torch.no_grad():
                emb = self.facenet(face_tensor)
                emb = F.normalize(emb)

            query = emb.squeeze(0).cpu().numpy().astype('float32').reshape(1, -1)
            distances, indices = self.index.search(query, k=1)
            dist, idx = distances[0][0], indices[0][0]

            recognized_person = self.face_ids[idx] if dist < self.threshold else "Unknown"

            if show:
                cv2.rectangle(img_orig, (x1, y1), (x2, y2), (0, 255, 0), 2)
                label = f"{recognized_person} ({dist:.2f})"
                cv2.putText(img_orig, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                            0.6, (0, 255, 0), 2, cv2.LINE_AA)
                plt.figure(figsize=(8, 8))
                plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
                plt.axis('off')
                plt.title("Result")
                plt.show()

            return recognized_person, dist

        return "NoFace", None

    def recognize_frame(self, frame):
        img_rgb = cv2.cvtColor(frame.copy(), cv2.COLOR_BGR2RGB)
        img_small = cv2.resize(img_rgb, (128, 128))
        h, w = frame.shape[:2]

        detections = self.detector.predict_on_image(img_small)
        results = []

        for det in detections:
            ymin, xmin, ymax, xmax = det[:4]
            x1, y1, x2, y2 = int(xmin * w), int(ymin * h), int(xmax * w), int(ymax * h)
            face_crop = img_rgb[y1:y2, x1:x2]
            if face_crop.size == 0:
                continue

            face_tensor = self.face_transform(face_crop).unsqueeze(0).to(self.device)
            with torch.no_grad():
                emb = self.facenet(face_tensor)
                emb = F.normalize(emb)

            query = emb.squeeze(0).cpu().numpy().astype('float32').reshape(1, -1)
            distances, indices = self.index.search(query, k=1)
            dist, idx = distances[0][0], indices[0][0]

            recognized_person = self.face_ids[idx] if dist < self.threshold else "Unknown"

            results.append((x1, y1, x2, y2, recognized_person, dist))

        return results

# %%
import torch
import gc
import time
import os

def evaluate_recognition(test_folder, recognizer):
    total, correct, unknown, total_time = 0, 0, 0, 0.0
    d_correct, d_wrong = [], []

    test_files = sorted([f for f in os.listdir(test_folder) if f.lower().endswith(('.jpg', '.png'))])

    for filename in test_files:
        true_id = filename.split('_')[0]
        img_path = os.path.join(test_folder, filename)

        start = time.time()
        pred_id, dist = recognizer.recognize(img_path, show=False)
        elapsed = time.time() - start
        total_time += elapsed
        total += 1

        if pred_id == true_id:
            correct += 1
            if dist is not None:
                d_correct.append(dist)
        elif pred_id == "Unknown":
            unknown += 1
            if dist is not None:
                d_wrong.append(dist)
        else:
            if dist is not None:
                d_wrong.append(dist)

        print(f"[{filename}] → GT: {true_id}, Pred: {pred_id}, Dist: {dist}, Time: {elapsed:.3f}s")

        # 🔁 Giải phóng bộ nhớ tạm
        torch.cuda.empty_cache()
        gc.collect()

    acc = correct / total if total else 0
    avg_time = total_time / total if total else 0
    avg_d_c = sum(d_correct)/len(d_correct) if d_correct else 0
    avg_d_w = sum(d_wrong)/len(d_wrong) if d_wrong else 0

    print("\n📊 Evaluation Summary:")
    print(f"📁 Total: {total}, ✅ Correct: {correct}, ❌ Wrong: {total - correct}, 🤷 Unknown: {unknown}")
    print(f"🎯 Accuracy: {acc*100:.2f}%, ⏱ Avg Time: {avg_time:.3f}s")
    print(f"📏 Avg Dist (Correct): {avg_d_c:.4f}, Avg Dist (Wrong): {avg_d_w:.4f}")

# %% [markdown]
# ### SPLITTING DATASET

# %%
def split_dataset(input_root, database_folder, test_folder):
    os.makedirs(database_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)

    people_folders = [f for f in os.listdir(input_root) if os.path.isdir(os.path.join(input_root, f))]

    for person in people_folders:
        person_path = os.path.join(input_root, person)
        all_images = sorted(os.listdir(person_path))  # đảm bảo thứ tự

        if len(all_images) < 2:
            print(f"⚠️ Bỏ qua {person} (ít hơn 2 ảnh)")
            continue

        # Ảnh đầu tiên → database
        db_img_src = os.path.join(person_path, all_images[0])
        db_img_dst = os.path.join(database_folder, f"{person}.jpg")
        shutil.copy(db_img_src, db_img_dst)

        # 99 ảnh còn lại → test_images
        for i, img_name in enumerate(all_images[1:], start=1):
            src = os.path.join(person_path, img_name)
            dst_name = f"{person}_{i}.jpg"
            dst = os.path.join(test_folder, dst_name)
            shutil.copy(src, dst)

        print(f"✅ Tách {person}: 1 ảnh vào database, {len(all_images)-1} ảnh vào test_images")

    print("\n🎉 Hoàn tất tách dataset!")

# %%
data_path = r'C:\Users\HP\Desktop\HK6\CS331\BlazeFace-PyTorch\Celebrity_Faces_Dataset'
db_img = r'C:\Users\HP\Desktop\HK6\CS331\BlazeFace-PyTorch\db_img'
test_img = r'C:\Users\HP\Desktop\HK6\CS331\BlazeFace-PyTorch\test_img'

blazeface_path = r'C:\Users\HP\Desktop\HK6\CS331\BlazeFace-PyTorch\blazeface.pth'
anchors_path = r'C:\Users\HP\Desktop\HK6\CS331\BlazeFace-PyTorch\anchors.npy'

# %%
# split_dataset(
#     input_root=data_path,
#     database_folder=db_img,
#     test_folder=test_img
# )

# %%
create_faiss_from_images(
    input_folder_path=db_img,
    index_path='face_index.faiss',
    id_mapping_path='face_ids.pkl',
    blazeface_path=blazeface_path,
    anchors_path=anchors_path
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 create_faiss_from_images(
#       2     input_folder_path=db_img,
#       3     index_path='face_index.faiss',
#       4     id_mapping_path='face_ids.pkl',
#       5     blazeface_path=blazeface_path,
#       6     anchors_path=anchors_path
#       7 )
#
# Cell In[6], line 16, in create_faiss_from_images(input_folder_path, index_path, id_mapping_path, blazeface_path, anchors_path)
#      13 facenet = torch.jit.load("models/mobilefacenet_scripted.pt", map_location=device)
#      14 facenet.eval()
# ---> 16 face_transform = transforms.Compose([
#      17     transforms.ToPILImage(),
#      18     transforms.Resize((160, 160)),
#      19     transforms.ToTensor(),
#      20     transforms.Normalize([0.5], [0.5])
#      21 ])
#      23 face_vectors = []
#      24 face_ids = []
#
# NameError: name 'transforms' is not defined

# %%
recognizer = FaceRecognizer(
    blazeface_path=blazeface_path,
    anchors_path=anchors_path,
    index_path='face_index.faiss',
    id_mapping_path='face_ids.pkl',
    threshold=0.95
)
# Out:
# 📂 FAISS index loaded:
#  - Số vector: 17
#  - Loại index: <class 'faiss.swigfaiss.IndexIVFFlat'>
#  - Chiều vector: 512

# %%
print("Số vector trong index:", recognizer.index.ntotal)
print("Kiểu FAISS index:", type(recognizer.index))
# Out:
# Số vector trong index: 17
# Kiểu FAISS index: <class 'faiss.swigfaiss.IndexIVFFlat'>

# %%
evaluate_recognition(test_img, recognizer)
# Out:
# [Angelina Jolie_1.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.3234807848930359, Time: 0.136s
# [Angelina Jolie_10.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.42916256189346313, Time: 0.108s
# [Angelina Jolie_11.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.2653766870498657, Time: 0.126s
# [Angelina Jolie_12.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.26576927304267883, Time: 0.100s
# [Angelina Jolie_13.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5724337100982666, Time: 0.104s
# [Angelina Jolie_14.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.4599061608314514, Time: 0.134s
# [Angelina Jolie_15.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.3038078844547272, Time: 0.102s
# [Angelina Jolie_16.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.6800921559333801, Time: 0.094s
# [Angelina Jolie_17.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5372225046157837, Time: 0.106s
# [Angelina Jolie_18.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.291118860244751, Time: 0.083s
# [Angelina Jolie_19.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.3680446743965149, Time: 0.106s
# [Angelina Jolie_2.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7369328141212463, Time: 0.111s
# [Angelina Jolie_20.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.663589358329773, Time: 0.116s
# [Angelina Jolie_21.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.2620554566383362, Time: 0.087s
# [Angelina Jolie_22.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5246269106864929, Time: 0.098s
# [Angelina Jolie_23.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8288930654525757, Time: 0.089s
# [Angelina Jolie_24.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.8511179089546204, Time: 0.081s
# [Angelina Jolie_25.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8132871985435486, Time: 0.088s
# [Angelina Jolie_26.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.4442451596260071, Time: 0.100s
# [Angelina Jolie_27.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5176810622215271, Time: 0.100s
# [Angelina Jolie_28.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9503045082092285, Time: 0.092s
# [Angelina Jolie_29.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5773953199386597, Time: 0.096s
# [Angelina Jolie_3.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.41111135482788086, Time: 0.090s
# [Angelina Jolie_30.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.44915246963500977, Time: 0.113s
# [Angelina Jolie_31.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.7061896324157715, Time: 0.100s
# [Angelina Jolie_32.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.37284940481185913, Time: 0.069s
# [Angelina Jolie_33.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.3232947587966919, Time: 0.092s
# [Angelina Jolie_34.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.764002799987793, Time: 0.074s
# [Angelina Jolie_35.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.407655268907547, Time: 0.096s
# [Angelina Jolie_36.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7764456868171692, Time: 0.105s
# [Angelina Jolie_37.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.44305115938186646, Time: 0.105s
# [Angelina Jolie_38.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.4934440851211548, Time: 0.110s
# [Angelina Jolie_39.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9642654657363892, Time: 0.107s
# [Angelina Jolie_4.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.38162314891815186, Time: 0.118s
# [Angelina Jolie_40.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.4772835075855255, Time: 0.081s
# [Angelina Jolie_41.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.3898269236087799, Time: 0.079s
# [Angelina Jolie_42.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.46678441762924194, Time: 0.089s
# [Angelina Jolie_43.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.609281063079834, Time: 0.109s
# [Angelina Jolie_44.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.33819380402565, Time: 0.100s
# [Angelina Jolie_45.jpg] → GT: Angelina Jolie, Pred: NoFace, Dist: None, Time: 0.015s
# [Angelina Jolie_46.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7126635313034058, Time: 0.080s
# [Angelina Jolie_47.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.4757046699523926, Time: 0.081s
# [Angelina Jolie_48.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.2667300701141357, Time: 0.080s
# [Angelina Jolie_49.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.88810133934021, Time: 0.099s
# [Angelina Jolie_5.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.512579083442688, Time: 0.100s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 evaluate_recognition(test_img, recognizer)
#
# Cell In[6], line 38, in evaluate_recognition(test_folder, recognizer)
#      36     # 🔁 Giải phóng bộ nhớ tạm
#      37     torch.cuda.empty_cache()
# ---> 38     gc.collect()
#      40 acc = correct / total if total else 0
#      41 avg_time = total_time / total if total else 0
#
# KeyboardInterrupt:

# %%
print("RAM còn lại:", psutil.virtual_memory().available / 1024**2, "MB")
# Out:
# RAM còn lại: 950.5859375 MB

# %%
def run_realtime_camera(recognizer):
    cap = cv2.VideoCapture(0)  # Dùng camera mặc định
    if not cap.isOpened():
        print("❌ Không thể mở camera.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Không đọc được frame từ camera.")
            break

        results = recognizer.recognize_frame(frame)

        for (x1, y1, x2, y2, name, dist) in results:
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"{name} ({dist:.2f})"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                        0.6, (0, 255, 0), 2, cv2.LINE_AA)

        cv2.imshow("Face Recognition Realtime", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):  # Nhấn q để thoát
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
recognizer = FaceRecognizer(
    blazeface_path=blazeface_path,
    anchors_path=anchors_path,
    index_path='face_index.faiss',
    id_mapping_path='face_ids.pkl',
    threshold=0.95
)

run_realtime_camera(recognizer)
# Out:
# 📂 FAISS index loaded:
#  - Số vector: 17
#  - Loại index: <class 'faiss.swigfaiss.IndexIVFFlat'>
#  - Chiều vector: 512

# %% [markdown]
# ### COMPUTE WITHOUT FAISS

# %%
def create_database(input_folder_path, output_folder_path):
    # Load mô hình BlazeFace chính diện
    front_net = BlazeFace().to(device)
    front_net.load_weights(blazeface_path)
    front_net.load_anchors(anchors_path)
    front_net.min_score_thresh = 0.7
    front_net.min_suppression_threshold = 0.3
    front_net.eval()

    facenet = InceptionResnetV1(pretrained='vggface2').eval().to(device)

    # Transform input face image
    face_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((160, 160)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])
    for filename in os.listdir(input_folder_path):
        img_path = os.path.join(input_folder_path, filename)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (128, 128))
        h, w, _ = img.shape

        detected_face = front_net.predict_on_image(img)

        for i, det in enumerate(detected_face):
            ymin, xmin, ymax, xmax = det[:4]
            x1 = int(xmin * w)
            y1 = int(ymin * h)
            x2 = int(xmax * w)
            y2 = int(ymax * h)

            # Cắt khuôn mặt từ ảnh gốc
            face_crop = img[y1:y2, x1:x2]
            if face_crop.size == 0:
                continue  # Tránh lỗi nếu crop ra vùng rỗng

            # Preprocess và đưa qua FaceNet
            face_tensor = face_transform(face_crop).unsqueeze(0).to(device)
            with torch.no_grad():
                embedding = facenet(face_tensor)  # (1, 512)
                embedding = F.normalize(embedding)  # L2 normalize (tuỳ chọn)
            output_name = f"{os.path.splitext(filename)[0]}_embedding.pt"
            output_path = os.path.join(output_folder_path, output_name)

            torch.save(embedding, output_path)
            # In ra hoặc lưu vector đặc trưng
            print("Đã lưu 1 vector embedding: ", output_name)

# %%
class BaselineRecognizer:
    def __init__(self, blazeface_path, anchors_path, embeddings_folder, threshold=0.95, device='cuda'):
        self.device = torch.device(device if torch.cuda.is_available() else 'cpu')
        self.threshold = threshold

        # Load BlazeFace
        self.detector = BlazeFace().to(self.device)
        self.detector.load_weights(blazeface_path)
        self.detector.load_anchors(anchors_path)
        self.detector.min_score_thresh = 0.7
        self.detector.min_suppression_threshold = 0.3
        self.detector.eval()

        # Load FaceNet
        self.facenet = InceptionResnetV1(pretrained='vggface2').eval().to(self.device)

        # Load embeddings
        self.embeddings = []
        self.ids = []
        for fname in os.listdir(embeddings_folder):
            if fname.endswith(".pt"):
                vector = torch.load(os.path.join(embeddings_folder, fname)).squeeze(0).to(self.device)
                person_id = fname.split("_")[0]
                self.embeddings.append(vector)
                self.ids.append(person_id)

        # Preprocess
        self.face_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((160, 160)),
            transforms.ToTensor(),
            transforms.Normalize([0.5], [0.5])
        ])

    def recognize(self, img_path, show=False):
        img_orig = cv2.imread(img_path)
        if img_orig is None:
            return "Invalid", None

        img_rgb = cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB)
        img_small = cv2.resize(img_rgb, (128, 128))
        h, w = img_orig.shape[:2]

        detections = self.detector.predict_on_image(img_small)
        if len(detections) == 0:
            return "NoFace", None

        for det in detections:
            ymin, xmin, ymax, xmax = det[:4]
            x1, y1, x2, y2 = int(xmin * w), int(ymin * h), int(xmax * w), int(ymax * h)
            face_crop = img_rgb[y1:y2, x1:x2]
            if face_crop.size == 0:
                continue

            face_tensor = self.face_transform(face_crop).unsqueeze(0).to(self.device)
            with torch.no_grad():
                emb = self.facenet(face_tensor)
                emb = F.normalize(emb).squeeze(0)

            # So sánh với tất cả vector
            min_dist = float("inf")
            best_match = "Unknown"
            for i, db_vector in enumerate(self.embeddings):
                dist = torch.dist(emb, db_vector).item()
                if dist < min_dist:
                    min_dist = dist
                    best_match = self.ids[i]

            if min_dist < self.threshold:
                return best_match, min_dist
            else:
                return "Unknown", min_dist

        return "NoFace", None

# %%
vector_db = '/content/drive/MyDrive/UIT/CS331/BlazeFace-PyTorch/vector_db'

create_database(db_img, vector_db)
# Out:
# Đã lưu 1 vector embedding:  Angelina Jolie_embedding.pt
# Đã lưu 1 vector embedding:  Will Smith_embedding.pt
# Đã lưu 1 vector embedding:  Tom Cruise_embedding.pt
# Đã lưu 1 vector embedding:  Tom Hanks_embedding.pt
# Đã lưu 1 vector embedding:  Johnny Depp_embedding.pt
# Đã lưu 1 vector embedding:  Leonardo DiCaprio_embedding.pt
# Đã lưu 1 vector embedding:  Natalie Portman_embedding.pt
# Đã lưu 1 vector embedding:  Sandra Bullock_embedding.pt
# Đã lưu 1 vector embedding:  Kate Winslet_embedding.pt
# Đã lưu 1 vector embedding:  Nicole Kidman_embedding.pt
# Đã lưu 1 vector embedding:  Robert Downey Jr_embedding.pt
# Đã lưu 1 vector embedding:  Jennifer Lawrence_embedding.pt
# Đã lưu 1 vector embedding:  Scarlett Johansson_embedding.pt
# Đã lưu 1 vector embedding:  Denzel Washington_embedding.pt
# Đã lưu 1 vector embedding:  Brad Pitt_embedding.pt
# Đã lưu 1 vector embedding:  Hugh Jackman_embedding.pt
# Đã lưu 1 vector embedding:  Megan Fox_embedding.pt

# %%
base_recognizer = BaselineRecognizer(
    blazeface_path=blazeface_path,
    anchors_path=anchors_path,
    embeddings_folder=vector_db,
    threshold=0.95
)

evaluate_recognition(test_img, base_recognizer)
# Out:
# [Angelina Jolie_1.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5687538981437683, Time: 0.126s
# [Angelina Jolie_2.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8584478497505188, Time: 0.114s
# [Angelina Jolie_3.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.641179621219635, Time: 0.141s
# [Angelina Jolie_4.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6177566647529602, Time: 0.121s
# [Angelina Jolie_5.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7159461975097656, Time: 0.117s
# [Angelina Jolie_6.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6132485270500183, Time: 0.148s
# [Angelina Jolie_7.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6602413654327393, Time: 0.115s
# [Angelina Jolie_8.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8319584131240845, Time: 0.141s
# [Angelina Jolie_9.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7751425504684448, Time: 0.105s
# [Angelina Jolie_10.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6551048755645752, Time: 0.132s
# [Angelina Jolie_11.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5151473879814148, Time: 0.196s
# [Angelina Jolie_12.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5155282020568848, Time: 0.160s
# [Angelina Jolie_13.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.756593644618988, Time: 0.210s
# [Angelina Jolie_14.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6781638860702515, Time: 0.170s
# [Angelina Jolie_15.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5511878132820129, Time: 0.234s
# [Angelina Jolie_16.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7727194428443909, Time: 0.444s
# [Angelina Jolie_17.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7329545021057129, Time: 0.287s
# [Angelina Jolie_18.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5395543575286865, Time: 0.491s
# [Angelina Jolie_19.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6066669821739197, Time: 19.519s
# [Angelina Jolie_20.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8146100044250488, Time: 0.103s
# [Angelina Jolie_21.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5119136571884155, Time: 0.122s
# [Angelina Jolie_22.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.724311351776123, Time: 0.104s
# [Angelina Jolie_23.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9104357957839966, Time: 0.105s
# [Angelina Jolie_24.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.9225603342056274, Time: 0.137s
# [Angelina Jolie_25.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9018244743347168, Time: 0.112s
# [Angelina Jolie_26.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6665171384811401, Time: 0.109s
# [Angelina Jolie_27.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7195006012916565, Time: 0.155s
# [Angelina Jolie_28.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9748355746269226, Time: 0.105s
# [Angelina Jolie_29.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7598656415939331, Time: 0.108s
# [Angelina Jolie_30.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6701885461807251, Time: 0.105s
# [Angelina Jolie_31.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.8403507471084595, Time: 0.108s
# [Angelina Jolie_32.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6106140613555908, Time: 0.116s
# [Angelina Jolie_33.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5685903429985046, Time: 0.132s
# [Angelina Jolie_34.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8740724921226501, Time: 0.106s
# [Angelina Jolie_35.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6384788155555725, Time: 0.116s
# [Angelina Jolie_36.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.881161630153656, Time: 0.127s
# [Angelina Jolie_37.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6656209230422974, Time: 0.119s
# [Angelina Jolie_38.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7024558186531067, Time: 0.113s
# [Angelina Jolie_39.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9819702506065369, Time: 0.116s
# [Angelina Jolie_40.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6908572316169739, Time: 0.107s
# [Angelina Jolie_41.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6243612766265869, Time: 0.113s
# [Angelina Jolie_42.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6832165122032166, Time: 0.109s
# [Angelina Jolie_43.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7805644869804382, Time: 0.109s
# [Angelina Jolie_44.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5815444588661194, Time: 0.117s
# [Angelina Jolie_45.jpg] → GT: Angelina Jolie, Pred: NoFace, Dist: None, Time: 0.023s
# [Angelina Jolie_46.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.844194233417511, Time: 0.126s
# [Angelina Jolie_47.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6897134184837341, Time: 0.107s
# [Angelina Jolie_48.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.1254910230636597, Time: 0.109s
# [Angelina Jolie_49.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9205502271652222, Time: 0.107s
# [Angelina Jolie_50.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.730466365814209, Time: 0.118s
# [Angelina Jolie_51.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6584070324897766, Time: 0.125s
# [Angelina Jolie_52.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7695403099060059, Time: 0.114s
# [Angelina Jolie_53.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7734932899475098, Time: 0.116s
# [Angelina Jolie_54.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9040469527244568, Time: 0.111s
# [Angelina Jolie_55.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9868664741516113, Time: 0.124s
# [Angelina Jolie_56.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.0022681951522827, Time: 0.106s
# [Angelina Jolie_57.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8406508564949036, Time: 0.107s
# [Angelina Jolie_58.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6227185726165771, Time: 0.108s
# [Angelina Jolie_59.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9856224060058594, Time: 0.106s
# [Angelina Jolie_60.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.9359679818153381, Time: 0.110s
# [Angelina Jolie_61.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6770240664482117, Time: 0.110s
# [Angelina Jolie_62.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6276301741600037, Time: 0.120s
# [Angelina Jolie_63.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9223188757896423, Time: 0.113s
# [Angelina Jolie_64.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9686839580535889, Time: 0.113s
# [Angelina Jolie_65.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7027019262313843, Time: 0.119s
# [Angelina Jolie_66.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8379785418510437, Time: 0.113s
# [Angelina Jolie_67.jpg] → GT: Angelina Jolie, Pred: NoFace, Dist: None, Time: 0.021s
# [Angelina Jolie_68.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8739967346191406, Time: 0.107s
# [Angelina Jolie_69.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6388529539108276, Time: 0.110s
# [Angelina Jolie_70.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6886326670646667, Time: 0.106s
# [Angelina Jolie_71.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5380573868751526, Time: 0.133s
# [Angelina Jolie_72.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8068516850471497, Time: 0.133s
# [Angelina Jolie_73.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8108628988265991, Time: 0.166s
# [Angelina Jolie_74.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8371279239654541, Time: 0.170s
# [Angelina Jolie_75.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7743114829063416, Time: 0.171s
# [Angelina Jolie_76.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8899095058441162, Time: 0.168s
# [Angelina Jolie_77.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7032100558280945, Time: 0.162s
# [Angelina Jolie_78.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.896884024143219, Time: 0.162s
# [Angelina Jolie_79.jpg] → GT: Angelina Jolie, Pred: NoFace, Dist: None, Time: 0.027s
# [Angelina Jolie_80.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5980046987533569, Time: 0.157s
# [Angelina Jolie_81.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.6434798240661621, Time: 0.192s
# [Angelina Jolie_82.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.0104970932006836, Time: 0.165s
# [Angelina Jolie_83.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.8713012337684631, Time: 0.167s
# [Angelina Jolie_84.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7700244784355164, Time: 0.162s
# [Angelina Jolie_85.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.55780428647995, Time: 0.162s
# [Angelina Jolie_86.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9631240367889404, Time: 0.160s
# [Angelina Jolie_87.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5429576635360718, Time: 0.159s
# [Angelina Jolie_88.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.8637819290161133, Time: 0.173s
# [Angelina Jolie_89.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9726167321205139, Time: 0.157s
# [Angelina Jolie_90.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.5741453170776367, Time: 0.166s
# [Angelina Jolie_91.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9605736136436462, Time: 0.168s
# [Angelina Jolie_92.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.689225435256958, Time: 0.162s
# [Angelina Jolie_93.jpg] → GT: Angelina Jolie, Pred: Megan Fox, Dist: 0.9247894883155823, Time: 0.167s
# [Angelina Jolie_94.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.8925093412399292, Time: 0.184s
# [Angelina Jolie_95.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.0829756259918213, Time: 0.163s
# [Angelina Jolie_96.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 1.0258657932281494, Time: 0.171s
# [Angelina Jolie_97.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.9009437561035156, Time: 0.132s
# [Angelina Jolie_98.jpg] → GT: Angelina Jolie, Pred: Unknown, Dist: 0.9969542622566223, Time: 0.116s
# [Angelina Jolie_99.jpg] → GT: Angelina Jolie, Pred: Angelina Jolie, Dist: 0.7509379982948303, Time: 0.102s
# [Will Smith_1.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6832554340362549, Time: 0.106s
# [Will Smith_2.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7290964722633362, Time: 0.106s
# [Will Smith_3.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7390655875205994, Time: 0.124s
# [Will Smith_4.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.4168056547641754, Time: 0.113s
# [Will Smith_5.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7629472613334656, Time: 0.112s
# [Will Smith_6.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7670268416404724, Time: 0.117s
# [Will Smith_7.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6609256863594055, Time: 0.117s
# [Will Smith_8.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.5830445885658264, Time: 0.113s
# [Will Smith_9.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7115400433540344, Time: 0.105s
# [Will Smith_10.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.625026524066925, Time: 0.106s
# [Will Smith_11.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7817290425300598, Time: 0.122s
# [Will Smith_12.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7743450403213501, Time: 0.124s
# [Will Smith_13.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6273800134658813, Time: 0.111s
# [Will Smith_14.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8194575905799866, Time: 0.108s
# [Will Smith_15.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.773252010345459, Time: 0.116s
# [Will Smith_16.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7325161695480347, Time: 0.112s
# [Will Smith_17.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.643516480922699, Time: 0.116s
# [Will Smith_18.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8146080374717712, Time: 0.109s
# [Will Smith_19.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7561203241348267, Time: 0.108s
# [Will Smith_20.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7913742065429688, Time: 0.109s
# [Will Smith_21.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6733077764511108, Time: 0.108s
# [Will Smith_22.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8009017705917358, Time: 0.121s
# [Will Smith_23.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7172642350196838, Time: 0.119s
# [Will Smith_24.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7619121074676514, Time: 0.114s
# [Will Smith_25.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7911302447319031, Time: 0.108s
# [Will Smith_26.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.5699118971824646, Time: 0.110s
# [Will Smith_27.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.670235276222229, Time: 0.112s
# [Will Smith_28.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7439693212509155, Time: 0.104s
# [Will Smith_29.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.9144666194915771, Time: 0.107s
# [Will Smith_30.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6191464066505432, Time: 0.111s
# [Will Smith_31.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7406985759735107, Time: 0.128s
# [Will Smith_32.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.637543261051178, Time: 0.114s
# [Will Smith_33.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.825994074344635, Time: 0.115s
# [Will Smith_34.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8676444292068481, Time: 0.109s
# [Will Smith_35.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8627569675445557, Time: 0.112s
# [Will Smith_36.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.641331672668457, Time: 0.106s
# [Will Smith_37.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8032880425453186, Time: 0.107s
# [Will Smith_38.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6697865128517151, Time: 0.104s
# [Will Smith_39.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8001394271850586, Time: 0.109s
# [Will Smith_40.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.5877012014389038, Time: 0.123s
# [Will Smith_41.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8161486983299255, Time: 0.110s
# [Will Smith_42.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6943018436431885, Time: 0.113s
# [Will Smith_43.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.817246675491333, Time: 0.114s
# [Will Smith_44.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7122172713279724, Time: 0.111s
# [Will Smith_45.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6755078434944153, Time: 0.107s
# [Will Smith_46.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6393508315086365, Time: 0.107s
# [Will Smith_47.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7298097014427185, Time: 0.108s
# [Will Smith_48.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8703984618186951, Time: 0.106s
# [Will Smith_49.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8996590375900269, Time: 0.109s
# [Will Smith_50.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7717398405075073, Time: 0.122s
# [Will Smith_51.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8393170237541199, Time: 0.113s
# [Will Smith_52.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7666164636611938, Time: 0.128s
# [Will Smith_53.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8175494074821472, Time: 0.110s
# [Will Smith_54.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8384367227554321, Time: 0.108s
# [Will Smith_55.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7725980281829834, Time: 0.114s
# [Will Smith_56.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.750219464302063, Time: 0.103s
# [Will Smith_57.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8833124041557312, Time: 0.108s
# [Will Smith_58.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6006240844726562, Time: 0.111s
# [Will Smith_59.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8294690251350403, Time: 0.122s
# [Will Smith_60.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7535372376441956, Time: 0.110s
# [Will Smith_61.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8977546691894531, Time: 0.110s
# [Will Smith_62.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.9257175326347351, Time: 0.109s
# [Will Smith_63.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6815972924232483, Time: 0.108s
# [Will Smith_64.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8810448050498962, Time: 0.102s
# [Will Smith_65.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7525426745414734, Time: 0.108s
# [Will Smith_66.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.811367392539978, Time: 0.113s
# [Will Smith_67.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.701694905757904, Time: 0.113s
# [Will Smith_68.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8428186774253845, Time: 0.119s
# [Will Smith_69.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7567837834358215, Time: 0.114s
# [Will Smith_70.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6108200550079346, Time: 0.111s
# [Will Smith_71.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7681156992912292, Time: 0.115s
# [Will Smith_72.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7574054598808289, Time: 0.105s
# [Will Smith_73.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6837482452392578, Time: 0.112s
# [Will Smith_74.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8828591108322144, Time: 0.108s
# [Will Smith_75.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.5847777724266052, Time: 0.113s
# [Will Smith_76.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.711764395236969, Time: 0.108s
# [Will Smith_77.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7134361267089844, Time: 0.109s
# [Will Smith_78.jpg] → GT: Will Smith, Pred: Unknown, Dist: 0.9574697017669678, Time: 0.126s
# [Will Smith_79.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7642961144447327, Time: 0.110s
# [Will Smith_80.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7618018984794617, Time: 0.111s
# [Will Smith_81.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7151936292648315, Time: 0.108s
# [Will Smith_82.jpg] → GT: Will Smith, Pred: NoFace, Dist: None, Time: 0.021s
# [Will Smith_83.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.5646918416023254, Time: 0.104s
# [Will Smith_84.jpg] → GT: Will Smith, Pred: Unknown, Dist: 0.9897699952125549, Time: 0.108s
# [Will Smith_85.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.9145498275756836, Time: 0.112s
# [Will Smith_86.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.811091959476471, Time: 0.112s
# [Will Smith_87.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7764016389846802, Time: 0.119s
# [Will Smith_88.jpg] → GT: Will Smith, Pred: Unknown, Dist: 1.0633032321929932, Time: 0.167s
# [Will Smith_89.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8889194130897522, Time: 0.184s
# [Will Smith_90.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6834292411804199, Time: 0.163s
# [Will Smith_91.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6844910979270935, Time: 0.155s
# [Will Smith_92.jpg] → GT: Will Smith, Pred: Unknown, Dist: 1.0522291660308838, Time: 0.176s
# [Will Smith_93.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6904190182685852, Time: 0.163s
# [Will Smith_94.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7725685834884644, Time: 0.182s
# [Will Smith_95.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.8387942910194397, Time: 0.159s
# [Will Smith_96.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.6612369418144226, Time: 0.167s
# [Will Smith_97.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7435367703437805, Time: 0.165s
# [Will Smith_98.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.9337501525878906, Time: 0.157s
# [Will Smith_99.jpg] → GT: Will Smith, Pred: Will Smith, Dist: 0.7323881983757019, Time: 0.165s
# [Tom Cruise_1.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5089907050132751, Time: 0.163s
# [Tom Cruise_2.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6144515872001648, Time: 0.165s
# [Tom Cruise_3.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8861181735992432, Time: 0.156s
# [Tom Cruise_4.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5540598034858704, Time: 0.155s
# [Tom Cruise_5.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5518463850021362, Time: 0.157s
# [Tom Cruise_6.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.68510502576828, Time: 0.157s
# [Tom Cruise_7.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5834397673606873, Time: 0.167s
# [Tom Cruise_8.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.44745051860809326, Time: 0.171s
# [Tom Cruise_9.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9330971837043762, Time: 0.177s
# [Tom Cruise_10.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5572989583015442, Time: 0.160s
# [Tom Cruise_11.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5572989583015442, Time: 0.167s
# [Tom Cruise_12.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8833726644515991, Time: 0.168s
# [Tom Cruise_13.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8833726644515991, Time: 0.133s
# [Tom Cruise_14.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6244018077850342, Time: 0.108s
# [Tom Cruise_15.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6244018077850342, Time: 0.110s
# [Tom Cruise_16.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5422868132591248, Time: 0.115s
# [Tom Cruise_17.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5422868132591248, Time: 0.109s
# [Tom Cruise_18.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.46068647503852844, Time: 0.105s
# [Tom Cruise_19.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.46068647503852844, Time: 0.107s
# [Tom Cruise_20.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9299468994140625, Time: 0.109s
# [Tom Cruise_21.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9299468994140625, Time: 0.107s
# [Tom Cruise_22.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.531775951385498, Time: 0.114s
# [Tom Cruise_23.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.531775951385498, Time: 0.115s
# [Tom Cruise_24.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7000914216041565, Time: 0.110s
# [Tom Cruise_25.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7000914216041565, Time: 0.121s
# [Tom Cruise_26.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.788881242275238, Time: 0.104s
# [Tom Cruise_27.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.788881242275238, Time: 0.109s
# [Tom Cruise_28.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7710056304931641, Time: 0.110s
# [Tom Cruise_29.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7710056304931641, Time: 0.120s
# [Tom Cruise_30.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5474768280982971, Time: 0.113s
# [Tom Cruise_31.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6834131479263306, Time: 0.119s
# [Tom Cruise_32.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7698258757591248, Time: 0.111s
# [Tom Cruise_33.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.42307528853416443, Time: 0.113s
# [Tom Cruise_34.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5965054631233215, Time: 0.140s
# [Tom Cruise_35.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6306021213531494, Time: 0.110s
# [Tom Cruise_36.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.4763774275779724, Time: 0.105s
# [Tom Cruise_37.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8287641406059265, Time: 0.117s
# [Tom Cruise_38.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9187399744987488, Time: 0.109s
# [Tom Cruise_39.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.4584271311759949, Time: 0.107s
# [Tom Cruise_40.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7599645853042603, Time: 0.120s
# [Tom Cruise_41.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5070962309837341, Time: 0.117s
# [Tom Cruise_42.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9499980211257935, Time: 0.108s
# [Tom Cruise_43.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6854836344718933, Time: 0.118s
# [Tom Cruise_44.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.86822509765625, Time: 0.108s
# [Tom Cruise_45.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7662105560302734, Time: 0.123s
# [Tom Cruise_46.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5771036148071289, Time: 0.122s
# [Tom Cruise_47.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8945079445838928, Time: 0.111s
# [Tom Cruise_48.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5847141742706299, Time: 0.111s
# [Tom Cruise_49.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7114213109016418, Time: 0.111s
# [Tom Cruise_50.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5326089859008789, Time: 0.110s
# [Tom Cruise_51.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5449526309967041, Time: 0.111s
# [Tom Cruise_52.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 1.209731936454773, Time: 0.111s
# [Tom Cruise_53.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5618003606796265, Time: 0.110s
# [Tom Cruise_54.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7749642729759216, Time: 0.107s
# [Tom Cruise_55.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8091362714767456, Time: 0.111s
# [Tom Cruise_56.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.567368745803833, Time: 0.106s
# [Tom Cruise_57.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9073813557624817, Time: 0.113s
# [Tom Cruise_58.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 1.202347755432129, Time: 0.109s
# [Tom Cruise_59.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7481605410575867, Time: 0.112s
# [Tom Cruise_60.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7768147587776184, Time: 0.107s
# [Tom Cruise_61.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9440094828605652, Time: 0.106s
# [Tom Cruise_62.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6571531891822815, Time: 0.128s
# [Tom Cruise_63.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.767800509929657, Time: 0.112s
# [Tom Cruise_64.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8116482496261597, Time: 0.105s
# [Tom Cruise_65.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.48842671513557434, Time: 0.112s
# [Tom Cruise_66.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.45142313838005066, Time: 0.113s
# [Tom Cruise_67.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8954571485519409, Time: 0.109s
# [Tom Cruise_68.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7588998079299927, Time: 0.109s
# [Tom Cruise_69.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6227613091468811, Time: 0.107s
# [Tom Cruise_70.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9204073548316956, Time: 0.105s
# [Tom Cruise_71.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7173287868499756, Time: 0.115s
# [Tom Cruise_72.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9393335580825806, Time: 0.106s
# [Tom Cruise_73.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.708873987197876, Time: 0.106s
# [Tom Cruise_74.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8797914981842041, Time: 0.131s
# [Tom Cruise_75.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5323938727378845, Time: 0.123s
# [Tom Cruise_76.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7292919754981995, Time: 0.107s
# [Tom Cruise_77.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7934445142745972, Time: 0.115s
# [Tom Cruise_78.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5251914262771606, Time: 0.107s
# [Tom Cruise_79.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.48515549302101135, Time: 0.110s
# [Tom Cruise_80.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7159591317176819, Time: 0.108s
# [Tom Cruise_81.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7363089919090271, Time: 0.121s
# [Tom Cruise_82.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8234848976135254, Time: 0.112s
# [Tom Cruise_83.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9448408484458923, Time: 0.108s
# [Tom Cruise_84.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7869244813919067, Time: 0.115s
# [Tom Cruise_85.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9119043946266174, Time: 0.114s
# [Tom Cruise_86.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8173816800117493, Time: 0.114s
# [Tom Cruise_87.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5424334406852722, Time: 0.106s
# [Tom Cruise_88.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7393070459365845, Time: 0.108s
# [Tom Cruise_89.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 1.0653551816940308, Time: 0.113s
# [Tom Cruise_90.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6650974750518799, Time: 0.125s
# [Tom Cruise_91.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8476094007492065, Time: 0.118s
# [Tom Cruise_92.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7847864031791687, Time: 0.113s
# [Tom Cruise_93.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8952484130859375, Time: 0.112s
# [Tom Cruise_94.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7242449522018433, Time: 0.111s
# [Tom Cruise_95.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5700634717941284, Time: 0.114s
# [Tom Cruise_96.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 1.0062212944030762, Time: 0.106s
# [Tom Cruise_97.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9412657022476196, Time: 0.109s
# [Tom Cruise_98.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 1.014556646347046, Time: 0.104s
# [Tom Cruise_99.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 0.9540311694145203, Time: 0.128s
# [Tom Cruise_100.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.7058921456336975, Time: 0.108s
# [Tom Cruise_101.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6475613713264465, Time: 0.111s
# [Tom Cruise_102.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.768561601638794, Time: 0.148s
# [Tom Cruise_103.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.5792587399482727, Time: 0.166s
# [Tom Cruise_104.jpg] → GT: Tom Cruise, Pred: Unknown, Dist: 0.9889410138130188, Time: 0.157s
# [Tom Cruise_105.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6731693744659424, Time: 0.156s
# [Tom Cruise_106.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.8381269574165344, Time: 0.157s
# [Tom Cruise_107.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.9306326508522034, Time: 0.164s
# [Tom Cruise_108.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.667084813117981, Time: 0.164s
# [Tom Cruise_109.jpg] → GT: Tom Cruise, Pred: Tom Cruise, Dist: 0.6389575600624084, Time: 0.158s
# [Tom Hanks_1.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6008943915367126, Time: 0.160s
# [Tom Hanks_2.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.041577935218811, Time: 0.158s
# [Tom Hanks_3.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7532801032066345, Time: 0.158s
# [Tom Hanks_4.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5480743646621704, Time: 0.173s
# [Tom Hanks_5.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.0481178760528564, Time: 0.172s
# [Tom Hanks_6.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.9371234178543091, Time: 0.183s
# [Tom Hanks_7.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6987844705581665, Time: 0.160s
# [Tom Hanks_8.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6795600652694702, Time: 0.153s
# [Tom Hanks_9.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6283108592033386, Time: 0.154s
# [Tom Hanks_10.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.125226378440857, Time: 0.161s
# [Tom Hanks_11.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8640325665473938, Time: 0.182s
# [Tom Hanks_12.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7187536358833313, Time: 0.170s
# [Tom Hanks_13.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6840983033180237, Time: 0.167s
# [Tom Hanks_14.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.613075315952301, Time: 0.160s
# [Tom Hanks_15.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7197434306144714, Time: 0.165s
# [Tom Hanks_16.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5488977432250977, Time: 0.179s
# [Tom Hanks_17.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6928965449333191, Time: 0.110s
# [Tom Hanks_18.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5361530184745789, Time: 0.119s
# [Tom Hanks_19.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6478037238121033, Time: 0.109s
# [Tom Hanks_20.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 0.9884326457977295, Time: 0.108s
# [Tom Hanks_21.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.907943606376648, Time: 0.100s
# [Tom Hanks_22.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6197652816772461, Time: 0.107s
# [Tom Hanks_23.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7596197724342346, Time: 0.099s
# [Tom Hanks_24.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6568486094474792, Time: 0.108s
# [Tom Hanks_25.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6405231356620789, Time: 0.108s
# [Tom Hanks_26.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.070183515548706, Time: 0.111s
# [Tom Hanks_27.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7231333255767822, Time: 0.125s
# [Tom Hanks_28.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5668777823448181, Time: 0.110s
# [Tom Hanks_29.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8307271599769592, Time: 0.106s
# [Tom Hanks_30.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6719509959220886, Time: 0.108s
# [Tom Hanks_31.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8978058099746704, Time: 0.102s
# [Tom Hanks_32.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6849226355552673, Time: 0.110s
# [Tom Hanks_33.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.75884610414505, Time: 0.105s
# [Tom Hanks_34.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8180615901947021, Time: 0.110s
# [Tom Hanks_35.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7076184749603271, Time: 0.107s
# [Tom Hanks_36.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6284183263778687, Time: 0.113s
# [Tom Hanks_37.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7595623135566711, Time: 0.125s
# [Tom Hanks_38.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7538507580757141, Time: 0.110s
# [Tom Hanks_39.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7581257820129395, Time: 0.104s
# [Tom Hanks_40.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.624650239944458, Time: 0.107s
# [Tom Hanks_41.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 0.9659591317176819, Time: 0.108s
# [Tom Hanks_42.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8979241251945496, Time: 0.111s
# [Tom Hanks_43.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6310572028160095, Time: 0.107s
# [Tom Hanks_44.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7797212600708008, Time: 0.108s
# [Tom Hanks_45.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8102845549583435, Time: 0.112s
# [Tom Hanks_46.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6567269563674927, Time: 0.146s
# [Tom Hanks_47.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6729028224945068, Time: 0.104s
# [Tom Hanks_48.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6326084136962891, Time: 0.109s
# [Tom Hanks_49.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6754311919212341, Time: 0.106s
# [Tom Hanks_50.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6633422374725342, Time: 0.107s
# [Tom Hanks_51.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7140923738479614, Time: 0.115s
# [Tom Hanks_52.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 0.9636631608009338, Time: 0.112s
# [Tom Hanks_53.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.0711394548416138, Time: 0.103s
# [Tom Hanks_54.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6385200619697571, Time: 0.115s
# [Tom Hanks_55.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.088926911354065, Time: 0.129s
# [Tom Hanks_56.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5618621706962585, Time: 0.114s
# [Tom Hanks_57.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6447385549545288, Time: 0.107s
# [Tom Hanks_58.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.0592360496520996, Time: 0.109s
# [Tom Hanks_59.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8016147613525391, Time: 0.106s
# [Tom Hanks_60.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7171093821525574, Time: 0.118s
# [Tom Hanks_61.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7137081623077393, Time: 0.112s
# [Tom Hanks_62.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.9436625242233276, Time: 0.113s
# [Tom Hanks_63.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6799710392951965, Time: 0.111s
# [Tom Hanks_64.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5581169128417969, Time: 0.108s
# [Tom Hanks_65.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.9418496489524841, Time: 0.119s
# [Tom Hanks_66.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7419586777687073, Time: 0.107s
# [Tom Hanks_67.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8085474371910095, Time: 0.106s
# [Tom Hanks_68.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8328015804290771, Time: 0.112s
# [Tom Hanks_69.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6576361060142517, Time: 0.128s
# [Tom Hanks_70.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8094427585601807, Time: 0.112s
# [Tom Hanks_71.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7541667222976685, Time: 0.109s
# [Tom Hanks_72.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6911650896072388, Time: 0.121s
# [Tom Hanks_73.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6671538949012756, Time: 0.117s
# [Tom Hanks_74.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6206481456756592, Time: 0.128s
# [Tom Hanks_75.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7130934596061707, Time: 0.106s
# [Tom Hanks_76.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6483963131904602, Time: 0.109s
# [Tom Hanks_77.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6936178803443909, Time: 0.105s
# [Tom Hanks_78.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7412052750587463, Time: 0.108s
# [Tom Hanks_79.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7449126243591309, Time: 0.110s
# [Tom Hanks_80.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6855407357215881, Time: 0.115s
# [Tom Hanks_81.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5968024730682373, Time: 0.109s
# [Tom Hanks_82.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.860004723072052, Time: 0.112s
# [Tom Hanks_83.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.69731605052948, Time: 0.121s
# [Tom Hanks_84.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5226425528526306, Time: 0.111s
# [Tom Hanks_85.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 0.9870970249176025, Time: 0.103s
# [Tom Hanks_86.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6736106276512146, Time: 0.129s
# [Tom Hanks_87.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6935141682624817, Time: 0.105s
# [Tom Hanks_88.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6966145634651184, Time: 0.109s
# [Tom Hanks_89.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.7469523549079895, Time: 0.107s
# [Tom Hanks_90.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6087767481803894, Time: 0.106s
# [Tom Hanks_91.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8560159206390381, Time: 0.108s
# [Tom Hanks_92.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.565130889415741, Time: 0.120s
# [Tom Hanks_93.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.8703604936599731, Time: 0.109s
# [Tom Hanks_94.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6279623508453369, Time: 0.106s
# [Tom Hanks_95.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.6331817507743835, Time: 0.107s
# [Tom Hanks_96.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.0885212421417236, Time: 0.110s
# [Tom Hanks_97.jpg] → GT: Tom Hanks, Pred: Unknown, Dist: 1.0497123003005981, Time: 0.107s
# [Tom Hanks_98.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.5763700008392334, Time: 0.112s
# [Tom Hanks_99.jpg] → GT: Tom Hanks, Pred: Tom Hanks, Dist: 0.9252827763557434, Time: 0.110s
# [Johnny Depp_1.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.851432740688324, Time: 0.119s
# [Johnny Depp_2.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6690500378608704, Time: 0.103s
# [Johnny Depp_3.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6980189085006714, Time: 0.127s
# [Johnny Depp_4.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8434488773345947, Time: 0.111s
# [Johnny Depp_5.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7117009162902832, Time: 0.111s
# [Johnny Depp_6.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.758432149887085, Time: 0.107s
# [Johnny Depp_7.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6795461177825928, Time: 0.125s
# [Johnny Depp_8.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7141208648681641, Time: 0.165s
# [Johnny Depp_9.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6820854544639587, Time: 0.163s
# [Johnny Depp_10.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7508237361907959, Time: 0.165s
# [Johnny Depp_11.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8046108484268188, Time: 0.179s
# [Johnny Depp_12.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8505098223686218, Time: 0.157s
# [Johnny Depp_13.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.610028862953186, Time: 0.158s
# [Johnny Depp_14.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.767038106918335, Time: 0.157s
# [Johnny Depp_15.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6917984485626221, Time: 0.167s
# [Johnny Depp_16.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7996684908866882, Time: 0.157s
# [Johnny Depp_17.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6897292137145996, Time: 0.179s
# [Johnny Depp_18.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6860398650169373, Time: 0.152s
# [Johnny Depp_19.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.536461353302002, Time: 0.159s
# [Johnny Depp_20.jpg] → GT: Johnny Depp, Pred: Unknown, Dist: 0.9988667368888855, Time: 0.158s
# [Johnny Depp_21.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8437474370002747, Time: 0.163s
# [Johnny Depp_22.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7643158435821533, Time: 0.153s
# [Johnny Depp_23.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8712185621261597, Time: 0.165s
# [Johnny Depp_24.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6444363594055176, Time: 0.174s
# [Johnny Depp_25.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8518054485321045, Time: 0.155s
# [Johnny Depp_26.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7415768504142761, Time: 0.174s
# [Johnny Depp_27.jpg] → GT: Johnny Depp, Pred: Unknown, Dist: 0.9597045183181763, Time: 0.179s
# [Johnny Depp_28.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7270236611366272, Time: 0.169s
# [Johnny Depp_29.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7494141459465027, Time: 0.164s
# [Johnny Depp_30.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8192427158355713, Time: 0.172s
# [Johnny Depp_31.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6480024456977844, Time: 0.155s
# [Johnny Depp_32.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7846904397010803, Time: 0.109s
# [Johnny Depp_33.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7194280028343201, Time: 0.114s
# [Johnny Depp_34.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.871641993522644, Time: 0.109s
# [Johnny Depp_35.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7854975461959839, Time: 0.115s
# [Johnny Depp_36.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.790290355682373, Time: 0.108s
# [Johnny Depp_37.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6215716600418091, Time: 0.110s
# [Johnny Depp_38.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7653301954269409, Time: 0.109s
# [Johnny Depp_39.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8116293549537659, Time: 0.123s
# [Johnny Depp_40.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7305461764335632, Time: 0.111s
# [Johnny Depp_41.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8024402856826782, Time: 0.110s
# [Johnny Depp_42.jpg] → GT: Johnny Depp, Pred: Unknown, Dist: 1.2041058540344238, Time: 0.110s
# [Johnny Depp_43.jpg] → GT: Johnny Depp, Pred: Unknown, Dist: 0.9565056562423706, Time: 0.115s
# [Johnny Depp_44.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6285049915313721, Time: 0.107s
# [Johnny Depp_45.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.9008105993270874, Time: 0.111s
# [Johnny Depp_46.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.9139803051948547, Time: 0.105s
# [Johnny Depp_47.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.675957977771759, Time: 0.108s
# [Johnny Depp_48.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6618816256523132, Time: 0.105s
# [Johnny Depp_49.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8645981550216675, Time: 0.124s
# [Johnny Depp_50.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8623787760734558, Time: 0.104s
# [Johnny Depp_51.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7340200543403625, Time: 0.112s
# [Johnny Depp_52.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7475387454032898, Time: 0.108s
# [Johnny Depp_53.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7335742115974426, Time: 0.113s
# [Johnny Depp_54.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8871256113052368, Time: 0.105s
# [Johnny Depp_55.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.5825125575065613, Time: 0.110s
# [Johnny Depp_56.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7890926599502563, Time: 0.107s
# [Johnny Depp_57.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6952877044677734, Time: 0.110s
# [Johnny Depp_58.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6941671371459961, Time: 0.119s
# [Johnny Depp_59.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8452172875404358, Time: 0.110s
# [Johnny Depp_60.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7170504331588745, Time: 0.112s
# [Johnny Depp_61.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7576844692230225, Time: 0.110s
# [Johnny Depp_62.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7826381325721741, Time: 0.108s
# [Johnny Depp_63.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7580930590629578, Time: 0.110s
# [Johnny Depp_64.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7806786894798279, Time: 0.115s
# [Johnny Depp_65.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6618310809135437, Time: 0.108s
# [Johnny Depp_66.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8832603096961975, Time: 0.113s
# [Johnny Depp_67.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8348846435546875, Time: 0.148s
# [Johnny Depp_68.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7364293932914734, Time: 0.110s
# [Johnny Depp_69.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7268475890159607, Time: 0.115s
# [Johnny Depp_70.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8593836426734924, Time: 0.110s
# [Johnny Depp_71.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.931281566619873, Time: 0.109s
# [Johnny Depp_72.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8005462884902954, Time: 0.106s
# [Johnny Depp_73.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6868997812271118, Time: 0.109s
# [Johnny Depp_74.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.722936749458313, Time: 0.106s
# [Johnny Depp_75.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7994157671928406, Time: 0.113s
# [Johnny Depp_76.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7234095335006714, Time: 0.113s
# [Johnny Depp_77.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7316154837608337, Time: 0.134s
# [Johnny Depp_78.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6967079639434814, Time: 0.109s
# [Johnny Depp_79.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7487584352493286, Time: 0.111s
# [Johnny Depp_80.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7018725872039795, Time: 0.106s
# [Johnny Depp_81.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7330301403999329, Time: 0.109s
# [Johnny Depp_82.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7714909315109253, Time: 0.108s
# [Johnny Depp_83.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.9159740805625916, Time: 0.115s
# [Johnny Depp_84.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8291013240814209, Time: 0.109s
# [Johnny Depp_85.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.7738775014877319, Time: 0.113s
# [Johnny Depp_86.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.9455291628837585, Time: 0.124s
# [Johnny Depp_87.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.6941758990287781, Time: 0.112s
# [Johnny Depp_88.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8022632002830505, Time: 0.106s
# [Johnny Depp_89.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.8790274858474731, Time: 0.109s
# [Johnny Depp_90.jpg] → GT: Johnny Depp, Pred: Unknown, Dist: 0.9692551493644714, Time: 0.103s
# [Johnny Depp_91.jpg] → GT: Johnny Depp, Pred: Johnny Depp, Dist: 0.770675539970398, Time: 0.107s
# ...
# [Hugh Jackman_33.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.1229054927825928, Time: 0.157s
# [Hugh Jackman_34.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8055896162986755, Time: 0.160s
# [Hugh Jackman_35.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7689385414123535, Time: 0.156s
# [Hugh Jackman_36.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8236271739006042, Time: 0.150s
# [Hugh Jackman_37.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 0.984409749507904, Time: 0.156s
# [Hugh Jackman_38.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8830617070198059, Time: 0.169s
# [Hugh Jackman_39.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.857836902141571, Time: 0.170s
# [Hugh Jackman_40.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8826661109924316, Time: 0.174s
# [Hugh Jackman_41.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7743213176727295, Time: 0.161s
# [Hugh Jackman_42.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.0196295976638794, Time: 0.162s
# [Hugh Jackman_43.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7606896758079529, Time: 0.164s
# [Hugh Jackman_44.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9470114707946777, Time: 0.163s
# [Hugh Jackman_45.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9221559762954712, Time: 0.169s
# [Hugh Jackman_46.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9396079182624817, Time: 0.155s
# [Hugh Jackman_47.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8034820556640625, Time: 0.168s
# [Hugh Jackman_48.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9165359139442444, Time: 0.176s
# [Hugh Jackman_49.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.1069610118865967, Time: 0.158s
# [Hugh Jackman_50.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9077190160751343, Time: 0.167s
# [Hugh Jackman_51.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8025699853897095, Time: 0.171s
# [Hugh Jackman_52.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9401022791862488, Time: 0.168s
# [Hugh Jackman_53.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.783326268196106, Time: 0.162s
# [Hugh Jackman_54.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7607318162918091, Time: 0.166s
# [Hugh Jackman_55.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8807717561721802, Time: 0.117s
# [Hugh Jackman_56.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8797501921653748, Time: 0.114s
# [Hugh Jackman_57.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9264838099479675, Time: 0.108s
# [Hugh Jackman_58.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8955615162849426, Time: 0.115s
# [Hugh Jackman_59.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 0.9976102113723755, Time: 0.145s
# [Hugh Jackman_60.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8152242302894592, Time: 0.119s
# [Hugh Jackman_61.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8213516473770142, Time: 0.114s
# [Hugh Jackman_62.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.06736421585083, Time: 0.108s
# [Hugh Jackman_63.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8377791047096252, Time: 0.154s
# [Hugh Jackman_64.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8797078728675842, Time: 0.113s
# [Hugh Jackman_65.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7663330435752869, Time: 0.106s
# [Hugh Jackman_66.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8690144419670105, Time: 0.123s
# [Hugh Jackman_67.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8301876187324524, Time: 0.100s
# [Hugh Jackman_68.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8583581447601318, Time: 0.149s
# [Hugh Jackman_69.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.6723795533180237, Time: 0.106s
# [Hugh Jackman_70.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.1144376993179321, Time: 0.112s
# [Hugh Jackman_71.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.817034900188446, Time: 0.133s
# [Hugh Jackman_72.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9484357833862305, Time: 0.115s
# [Hugh Jackman_73.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8936200737953186, Time: 0.111s
# [Hugh Jackman_74.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7049872279167175, Time: 0.131s
# [Hugh Jackman_75.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.889594316482544, Time: 0.113s
# [Hugh Jackman_76.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.807084321975708, Time: 0.121s
# [Hugh Jackman_77.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.831114649772644, Time: 0.118s
# [Hugh Jackman_78.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8537124991416931, Time: 0.109s
# [Hugh Jackman_79.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.770237922668457, Time: 0.104s
# [Hugh Jackman_80.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8928479552268982, Time: 0.111s
# [Hugh Jackman_81.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8874258995056152, Time: 0.107s
# [Hugh Jackman_82.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8862056136131287, Time: 0.107s
# [Hugh Jackman_83.jpg] → GT: Hugh Jackman, Pred: NoFace, Dist: None, Time: 0.023s
# [Hugh Jackman_84.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.0487558841705322, Time: 0.107s
# [Hugh Jackman_85.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.0657336711883545, Time: 0.111s
# [Hugh Jackman_86.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9411715865135193, Time: 0.117s
# [Hugh Jackman_87.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8154261708259583, Time: 0.141s
# [Hugh Jackman_88.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8324528336524963, Time: 0.106s
# [Hugh Jackman_89.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.880896806716919, Time: 0.111s
# [Hugh Jackman_90.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.0693094730377197, Time: 0.106s
# [Hugh Jackman_91.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.7494120001792908, Time: 0.114s
# [Hugh Jackman_92.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.812495768070221, Time: 0.105s
# [Hugh Jackman_93.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8139053583145142, Time: 0.120s
# [Hugh Jackman_94.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.084703803062439, Time: 0.107s
# [Hugh Jackman_95.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 1.0890777111053467, Time: 0.111s
# [Hugh Jackman_96.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8634494543075562, Time: 0.123s
# [Hugh Jackman_97.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.9156050682067871, Time: 0.110s
# [Hugh Jackman_98.jpg] → GT: Hugh Jackman, Pred: Unknown, Dist: 0.9918465614318848, Time: 0.110s
# [Hugh Jackman_99.jpg] → GT: Hugh Jackman, Pred: Hugh Jackman, Dist: 0.8644818663597107, Time: 0.106s
# [Megan Fox_1.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6748664379119873, Time: 0.107s
# [Megan Fox_2.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.4654228091239929, Time: 0.109s
# [Megan Fox_3.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6444064378738403, Time: 0.104s
# [Megan Fox_4.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7137429714202881, Time: 0.108s
# [Megan Fox_5.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7606843113899231, Time: 0.109s
# [Megan Fox_6.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8402056694030762, Time: 0.132s
# [Megan Fox_7.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.613639235496521, Time: 0.104s
# [Megan Fox_8.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.9320763349533081, Time: 0.105s
# [Megan Fox_9.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7802679538726807, Time: 0.107s
# [Megan Fox_10.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6994776725769043, Time: 0.115s
# [Megan Fox_11.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7950270175933838, Time: 0.107s
# [Megan Fox_12.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6615603566169739, Time: 0.114s
# [Megan Fox_13.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7419332265853882, Time: 0.107s
# [Megan Fox_14.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8278388381004333, Time: 0.117s
# [Megan Fox_15.jpg] → GT: Megan Fox, Pred: Unknown, Dist: 1.210124135017395, Time: 0.104s
# [Megan Fox_16.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.588798463344574, Time: 0.124s
# [Megan Fox_17.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7711536884307861, Time: 0.110s
# [Megan Fox_18.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6552789807319641, Time: 0.110s
# [Megan Fox_19.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.5622367262840271, Time: 0.105s
# [Megan Fox_20.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8081303834915161, Time: 0.107s
# [Megan Fox_21.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8020833134651184, Time: 0.106s
# [Megan Fox_22.jpg] → GT: Megan Fox, Pred: Unknown, Dist: 1.1048582792282104, Time: 0.108s
# [Megan Fox_23.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8477087616920471, Time: 0.109s
# [Megan Fox_24.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.763344943523407, Time: 0.113s
# [Megan Fox_25.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6675035953521729, Time: 0.120s
# [Megan Fox_26.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8037252426147461, Time: 0.108s
# [Megan Fox_27.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7465142011642456, Time: 0.136s
# [Megan Fox_28.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7386781573295593, Time: 0.113s
# [Megan Fox_29.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.735828161239624, Time: 0.109s
# [Megan Fox_30.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8059722781181335, Time: 0.109s
# [Megan Fox_31.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6863815188407898, Time: 0.106s
# [Megan Fox_32.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.5887463092803955, Time: 0.113s
# [Megan Fox_33.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8300043344497681, Time: 0.109s
# [Megan Fox_34.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8076456785202026, Time: 0.132s
# [Megan Fox_35.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.724463701248169, Time: 0.107s
# [Megan Fox_36.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7180773019790649, Time: 0.111s
# [Megan Fox_37.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6852223873138428, Time: 0.110s
# [Megan Fox_38.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.827508807182312, Time: 0.110s
# [Megan Fox_39.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6117100119590759, Time: 0.110s
# [Megan Fox_40.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7084118127822876, Time: 0.110s
# [Megan Fox_41.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.796380341053009, Time: 0.114s
# [Megan Fox_42.jpg] → GT: Megan Fox, Pred: Unknown, Dist: 0.9996317028999329, Time: 0.110s
# [Megan Fox_43.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8846098184585571, Time: 0.105s
# [Megan Fox_44.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7945725917816162, Time: 0.122s
# [Megan Fox_45.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8729512095451355, Time: 0.157s
# [Megan Fox_46.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.915137767791748, Time: 0.164s
# [Megan Fox_47.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.9373894929885864, Time: 0.163s
# [Megan Fox_48.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8491816520690918, Time: 0.158s
# [Megan Fox_49.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6730666756629944, Time: 0.174s
# [Megan Fox_50.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7249900698661804, Time: 0.160s
# [Megan Fox_51.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8971457481384277, Time: 0.173s
# [Megan Fox_52.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7837591171264648, Time: 0.172s
# [Megan Fox_53.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8506107330322266, Time: 0.217s
# [Megan Fox_54.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7760274410247803, Time: 0.161s
# [Megan Fox_55.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6441395878791809, Time: 0.188s
# [Megan Fox_56.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.5218993425369263, Time: 0.160s
# [Megan Fox_57.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7699949145317078, Time: 0.160s
# [Megan Fox_58.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7147879600524902, Time: 0.158s
# [Megan Fox_59.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7104067206382751, Time: 0.218s
# [Megan Fox_60.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.9062155485153198, Time: 0.167s
# [Megan Fox_61.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6704022884368896, Time: 0.187s
# [Megan Fox_62.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7389539480209351, Time: 0.175s
# [Megan Fox_63.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7025387287139893, Time: 0.183s
# [Megan Fox_64.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6129691004753113, Time: 0.174s
# [Megan Fox_65.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6539000272750854, Time: 0.181s
# [Megan Fox_66.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.635706901550293, Time: 0.159s
# [Megan Fox_67.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8426006436347961, Time: 0.159s
# [Megan Fox_68.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7727159261703491, Time: 0.187s
# [Megan Fox_69.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6234325170516968, Time: 0.131s
# [Megan Fox_70.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.90997713804245, Time: 0.109s
# [Megan Fox_71.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8473488092422485, Time: 0.112s
# [Megan Fox_72.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8037579655647278, Time: 0.109s
# [Megan Fox_73.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7663778066635132, Time: 0.114s
# [Megan Fox_74.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8493956327438354, Time: 0.106s
# [Megan Fox_75.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8223593235015869, Time: 0.112s
# [Megan Fox_76.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8323916792869568, Time: 0.107s
# [Megan Fox_77.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6295258402824402, Time: 0.110s
# [Megan Fox_78.jpg] → GT: Megan Fox, Pred: Unknown, Dist: 0.9810047745704651, Time: 0.127s
# [Megan Fox_79.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7764451503753662, Time: 0.119s
# [Megan Fox_80.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8715463876724243, Time: 0.104s
# [Megan Fox_81.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6884602904319763, Time: 0.114s
# [Megan Fox_82.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8670552372932434, Time: 0.107s
# [Megan Fox_83.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7043659090995789, Time: 0.116s
# [Megan Fox_84.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7558940649032593, Time: 0.107s
# [Megan Fox_85.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7453904151916504, Time: 0.110s
# [Megan Fox_86.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7923822402954102, Time: 0.104s
# [Megan Fox_87.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7330502867698669, Time: 0.110s
# [Megan Fox_88.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.5353336930274963, Time: 0.124s
# [Megan Fox_89.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7155297994613647, Time: 0.110s
# [Megan Fox_90.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7675150036811829, Time: 0.110s
# [Megan Fox_91.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7627636790275574, Time: 0.108s
# [Megan Fox_92.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7873333692550659, Time: 0.106s
# [Megan Fox_93.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.6208332777023315, Time: 0.111s
# [Megan Fox_94.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7561557292938232, Time: 0.106s
# [Megan Fox_95.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.8319483995437622, Time: 0.110s
# [Megan Fox_96.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.592698335647583, Time: 0.106s
# [Megan Fox_97.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.856049656867981, Time: 0.127s
# [Megan Fox_98.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.7200625538825989, Time: 0.108s
# [Megan Fox_99.jpg] → GT: Megan Fox, Pred: Megan Fox, Dist: 0.9336257576942444, Time: 0.115s
#
# 📊 Evaluation Summary:
# 📁 Total: 1793, ✅ Correct: 1588, ❌ Wrong: 205, 🤷 Unknown: 189
# 🎯 Accuracy: 88.57%, ⏱ Avg Time: 0.138s
# 📏 Avg Dist (Correct): 0.7423, Avg Dist (Wrong): 1.0212

# %% [markdown]
# ### DECOGNIZE WITH CAMERA
